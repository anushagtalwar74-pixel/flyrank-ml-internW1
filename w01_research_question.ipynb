# %% [markdown]
# <a href="https://colab.research.google.com/github/anushagtalwar74-pixel/flyrank-ml-internW1/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the Content Refresh Prioritization lane because many web pages lose traffic over time. My goal is to identify pages that are likely declining so they can be refreshed first. This project can help content teams focus on the pages that need attention instead of reviewing every page manually.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Which content pages should be refreshed first?
#
# Action: The SEO or content team refreshes the highest-priority pages.
#
# Cost of a wrong recommendation: If a healthy page is selected, time is wasted. If a declining page is missed, the website may continue losing search traffic and potential visitors.
#
# Why ML helps: Machine learning can identify patterns from historical search performance and help rank pages for review more efficiently than simple manual rules.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import subprocess

if not os.path.exists("flyrank-ml-internship-starter"):
    subprocess.run([
        "git",
        "clone",
        "https://github.com/flyrank-bih/flyrank-ml-internship-starter.git"
    ])

os.chdir("flyrank-ml-internship-starter")

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# Rows: 30000
# Columns: 44

# %% [markdown]
# The starter dataset contains thousands of content pages with multiple SEO-related features. The distribution of trend directions shows that some pages are declining while others are stable or growing. The average CTR and search volume demonstrate that page performance varies significantly, making content refresh prioritization a useful machine learning problem.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project provides **observed**, **measured**, and **directional** insights based on historical search performance data. The results are intended for **decision support** only. The project does **not** prove causation, predict Google's ranking algorithm, or guarantee future search performance.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
